# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **My name is Pamanji Jagadesh**
# I'm a graduated student, learning Data Science is my prime duty of the entire day.

# %% [markdown]
# *I am interested in data science because, i would love to contribute towards affordable and quality helthcare in the future.*

# %% [markdown]
# ### In the below cell I'm trying to print the name of my native place.

# %%
print("Dugaraja Patnam")
# Out:
# Dugaraja Patnam

# %% [markdown]
# ### Horizontal rule shown below.
# ***
# * this is the example for bulleted list
# * This is alson an another example for bulleted list.
# ***
# 1. Numbered list.
# 2. Numbered list.
# 3. Example for Numbered list.

# %% [markdown]
# |Name||Place||Date|
# |-||-||-|
# |Jagadesh||Dugaraja patnam||28th july, 2022|

# %% [markdown]
# [naa anveshana](www.youtube.com/naaanveshana)
